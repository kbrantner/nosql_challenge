# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `Ymongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'West Cottage',
#  'AddressLine2': 'South Foreland Lighthouse',
#  'AddressLine3': 'The Front',
#  'AddressLine4': 'St Margarets Bay',
#  'BusinessName': 'Mrs Knotts Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.492467848017,
#  'FHRSID': 429991,
#  'LocalAuthorityBusinessID': 'PI/000055200',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6HP',
#  'RatingDate': '2019-05-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64434db3dc652f161359988e'),
#  'geocode': {'latitude': '51.14061', 'longitude': '1.371894'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/429991',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_place={"BusinessName":"Penang Flavours",
           "LocalAuthorityName": "Greenwich"}

# %%
establishments.insert_one(new_place)

# %%
# Check that the new restaurant was inserted
query = {"BusinessName":"Penang Flavours"}
results = establishments.find(query)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('64435178713aad7487ca2b5d'), 'BusinessName': 'Penang Flavours', 'LocalAuthorityName': 'Greenwich'}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID':1, 'BusinessType':1 }
results = establishments.find(query, fields)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('64434db3dc652f161359988e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359988f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599890'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599891'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599893'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599896'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599897'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599899'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359989b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998a1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998a6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998af'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998bd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998c0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998c1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998c3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998cc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998cf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998d1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998d3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998d8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998db'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998e2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998e3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998e9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998f6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998f9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998fa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135998fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599900'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599901'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599906'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359990f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599910'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599914'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599917'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599918'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599919'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359991a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359991c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359991d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599923'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359992a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359992b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359992e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599933'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599939'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359993b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359993d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359993e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359993f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599948'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599949'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359994f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599954'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599955'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599956'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599959'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359995b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599964'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599966'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359996d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359997b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359997c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359997d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359997f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599988'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359998b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359998c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599990'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599991'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f161359999f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999a1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999a7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999b6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999ba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999bf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999c7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999c8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999c9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999cf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999d0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999d3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999d4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999d6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999d8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999db'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999e2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999e3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999e9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999eb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999f6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999fc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f16135999fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a09'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a0b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a0c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a0f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a1a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a28'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a2b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a38'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a3b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a3c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a45'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a46'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a4a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a50'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a52'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a56'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a5b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a5e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a5f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a66'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a73'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a7e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599a89'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599aa5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599aaf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ab0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ab4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ab5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599aba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ac9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599adb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599af4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599af9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b05'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b08'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b0b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b28'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b2a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b30'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b33'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b3b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b3c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b40'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b44'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b45'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b48'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b52'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b53'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b58'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b63'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b68'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b6b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b70'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b74'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b80'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b86'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b98'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b9b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599b9f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ba3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ba4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ba8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ba9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bc1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bc3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bcd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bd1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bd2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bd4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bd5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bd7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bd8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599be0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599be1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599be6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599be7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bf0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bf1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bf5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bfb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bfc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599bfe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c04'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c06'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c09'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c0d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c11'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c15'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c19'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c1b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c21'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c26'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c2c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c31'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c3a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c3b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c3d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c46'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c4b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c4d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c4f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c50'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c53'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c59'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c5a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c5c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c5d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c5e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c5f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c60'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c62'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c68'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c6a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c6b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c6d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c7b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c7c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c7f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c85'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c87'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c89'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c8a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c8b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c8c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c8e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c90'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c96'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c99'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599c9b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ca7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cbd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cc7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ccf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cd3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cd4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cd8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cda'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cef'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cf4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cf7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cf8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cf9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599cfc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d0b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d0c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d0d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d0e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d0f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d12'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d14'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d15'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d16'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d1d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d2b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d2c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d2f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d30'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d32'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d33'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d36'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d39'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d3f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d41'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d44'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d48'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d4b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d4c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d4d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d52'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d53'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d56'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d60'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d61'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d62'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d68'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d69'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d72'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d74'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d7b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d7c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d7d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d82'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d86'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d89'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d91'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d97'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599d9e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599da0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599da3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599da5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599da9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599daf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599db8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dbb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dbf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dc5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dc6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dc7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dc8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dd1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dd2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dd5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ddf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599de1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599de3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599de6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599de8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599de9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599deb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dee'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599def'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599df1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599df2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599df3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599df6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599df7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599df8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599df9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dfa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dfe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599dff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e00'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e01'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e03'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e04'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e05'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e08'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e0b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e0d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e15'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e16'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e1a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e23'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e26'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e28'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e2a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e2f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e31'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e39'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e3c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e4b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e51'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e5b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e5e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e61'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e66'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e6f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e75'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e7b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e7d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e7e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e82'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e88'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e8c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e90'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e9b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599e9c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ea2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ea4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599eab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599eaf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599eb0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599eb7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ebb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ec0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599eca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db3dc652f1613599ecd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...
# {'_id': ObjectId('64434db7dc652f16135a31d6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31d7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31db'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31de'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31e0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31ee'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31ef'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31f6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31fc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a31ff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3204'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3205'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3206'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3208'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3209'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a320b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a320c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a320d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3212'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3213'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3214'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3215'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3218'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a321a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a321b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a321e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3220'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3226'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3229'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a322a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a322b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a322c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a322d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a322e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3232'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a323a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a323c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a323f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3244'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3246'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3247'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3250'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3255'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3256'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a325c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3263'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3284'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a328b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a328e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3292'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3295'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3297'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3298'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a329b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a329c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a329f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32a0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32a1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32b3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32b7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32c3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32c6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32cb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32d4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32d6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32de'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32e0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32e5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a32f9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3300'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3304'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a330f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3311'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3316'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a331b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a331f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3323'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3327'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a332d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3332'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a333b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a333e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3340'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3341'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3342'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3344'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3347'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3348'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3349'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a334a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a334b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a334d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a334f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3351'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3352'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3356'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3357'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3359'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a335b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a335d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a335e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a335f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3360'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3363'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3368'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3369'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a336e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a336f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3371'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3374'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a337a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a337e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a337f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3382'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3390'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3394'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3396'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3397'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a3398'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a339d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a339e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33aa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33b3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33b4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33bc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33c9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33d4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33d5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64434db7dc652f16135a33f0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one(
    {"BusinessName":"Penang Flavours"},
    {'$push':
        {'BusinessTypeID': '1'}
     }
)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
results = establishments.find(query)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('64435178713aad7487ca2b5d'), 'BusinessName': 'Penang Flavours', 'LocalAuthorityName': 'Greenwich', 'BusinessTypeID': ['1']}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': "Dover"}
print(establishments.count_documents(query))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
results = establishments.find(query)
for result in results:
    print(result)

# %%
# Check that other documents remain with 'find_one'

establishments.find_one({})
# Out:
# {'_id': ObjectId('64434db3dc652f1613599b74'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude
establishments.update_many({}, [ {'$set':{ "geocode.longitude" : {'$toDouble': "$geocode.longitude"}}} ])

# %%
# Change the data type from String to Decimal for latitude
establishments.update_many({}, [ {'$set':{ "geocode.latitude" : {'$toDouble': "$geocode.latitude"}}} ])

# %%
# Check that the coordinates are now numbers
